# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
def get_stars(year):
    url = f'https://www.basketball-reference.com/leagues/NBA_{ year }_per_game.html'
    html = urlopen(url)
    soup = BeautifulSoup(html)
    headers = [title.strong.getText() for title in soup.findAll('p') if title.strong]
    stars = [name.a.getText() for name in soup.findAll('p')[2:] if name.a]
    headers = headers[:7]
    stars = stars[:7]
    summary = pd.DataFrame(data = stars).T
    summary.columns = headers
    summary.insert(0,'Year',year)
    return summary

# %%
year_range = range(1985,2020)
summary = pd.DataFrame()
for year in year_range:
    stats = get_stars(year)
    summary = pd.concat([summary,stats])
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 0
# Data columns (total 8 columns):
# Year                    35 non-null int64
# League Champion         35 non-null object
# Most Valuable Player    35 non-null object
# Rookie of the Year      35 non-null object
# PPG Leader              35 non-null object
# RPG Leader              35 non-null object
# APG Leader              35 non-null object
# WS Leader               35 non-null object
# dtypes: int64(1), object(7)
# memory usage: 2.5+ KB

# %%
summary
# Out:
#    Year        League Champion   Most Valuable Player  \
# 0  1985     Los Angeles Lakers             Larry Bird
# 0  1986         Boston Celtics             Larry Bird
# 0  1987     Los Angeles Lakers          Magic Johnson
# 0  1988     Los Angeles Lakers         Michael Jordan
# 0  1989        Detroit Pistons          Magic Johnson
# 0  1990        Detroit Pistons          Magic Johnson
# 0  1991          Chicago Bulls         Michael Jordan
# 0  1992          Chicago Bulls         Michael Jordan
# 0  1993          Chicago Bulls        Charles Barkley
# 0  1994        Houston Rockets        Hakeem Olajuwon
# 0  1995        Houston Rockets         David Robinson
# 0  1996          Chicago Bulls         Michael Jordan
# 0  1997          Chicago Bulls            Karl Malone
# 0  1998          Chicago Bulls         Michael Jordan
# 0  1999      San Antonio Spurs            Karl Malone
# 0  2000     Los Angeles Lakers       Shaquille O'Neal
# 0  2001     Los Angeles Lakers          Allen Iverson
# 0  2002     Los Angeles Lakers             Tim Duncan
# 0  2003      San Antonio Spurs             Tim Duncan
# 0  2004        Detroit Pistons          Kevin Garnett
# 0  2005      San Antonio Spurs             Steve Nash
# 0  2006             Miami Heat             Steve Nash
# 0  2007      San Antonio Spurs          Dirk Nowitzki
# 0  2008         Boston Celtics            Kobe Bryant
# 0  2009     Los Angeles Lakers           LeBron James
# 0  2010     Los Angeles Lakers           LeBron James
# 0  2011       Dallas Mavericks           Derrick Rose
# 0  2012             Miami Heat           LeBron James
# 0  2013             Miami Heat           LeBron James
# 0  2014      San Antonio Spurs           Kevin Durant
# 0  2015  Golden State Warriors          Stephen Curry
# 0  2016    Cleveland Cavaliers          Stephen Curry
# 0  2017  Golden State Warriors      Russell Westbrook
# 0  2018  Golden State Warriors           James Harden
# 0  2019        Toronto Raptors  Giannis Antetokounmpo
#
#         Rookie of the Year         PPG Leader        RPG Leader  \
# 0           Michael Jordan       Bernard King      Moses Malone
# 0            Patrick Ewing  Dominique Wilkins     Bill Laimbeer
# 0             Chuck Person     Michael Jordan   Charles Barkley
# 0             Mark Jackson     Michael Jordan      Michael Cage
# 0           Mitch Richmond     Michael Jordan   Hakeem Olajuwon
# 0           David Robinson     Michael Jordan   Hakeem Olajuwon
# 0          Derrick Coleman     Michael Jordan    David Robinson
# 0            Larry Johnson     Michael Jordan     Dennis Rodman
# 0         Shaquille O'Neal     Michael Jordan     Dennis Rodman
# 0             Chris Webber     David Robinson     Dennis Rodman
# 0               Grant Hill   Shaquille O'Neal     Dennis Rodman
# 0         Damon Stoudamire     Michael Jordan     Dennis Rodman
# 0            Allen Iverson     Michael Jordan     Dennis Rodman
# 0               Tim Duncan     Michael Jordan     Dennis Rodman
# 0             Vince Carter      Allen Iverson      Chris Webber
# 0              Elton Brand   Shaquille O'Neal   Dikembe Mutombo
# 0              Mike Miller      Allen Iverson   Dikembe Mutombo
# 0                Pau Gasol      Allen Iverson       Ben Wallace
# 0        Amar'e Stoudemire      Tracy McGrady       Ben Wallace
# 0             LeBron James      Tracy McGrady     Kevin Garnett
# 0             Emeka Okafor      Allen Iverson     Kevin Garnett
# 0               Chris Paul        Kobe Bryant     Kevin Garnett
# 0              Brandon Roy        Kobe Bryant     Kevin Garnett
# 0             Kevin Durant       LeBron James     Dwight Howard
# 0             Derrick Rose        Dwyane Wade     Dwight Howard
# 0             Tyreke Evans       Kevin Durant     Dwight Howard
# 0            Blake Griffin       Kevin Durant        Kevin Love
# 0             Kyrie Irving       Kevin Durant     Dwight Howard
# 0           Damian Lillard    Carmelo Anthony     Dwight Howard
# 0  Michael Carter-Williams       Kevin Durant    DeAndre Jordan
# 0           Andrew Wiggins  Russell Westbrook    DeAndre Jordan
# 0       Karl-Anthony Towns      Stephen Curry    Andre Drummond
# 0          Malcolm Brogdon  Russell Westbrook  Hassan Whiteside
# 0              Ben Simmons       James Harden    Andre Drummond
# 0              Luka Dončić       James Harden    Andre Drummond
#
#           APG Leader         WS Leader
# 0       Isiah Thomas        Larry Bird
# 0      Magic Johnson        Larry Bird
# 0      Magic Johnson    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    Michael Jordan
# 0      John Stockton    David Robinson
# 0      John Stockton    David Robinson
# 0      John Stockton    Michael Jordan
# 0       Mark Jackson    Michael Jordan
# 0     Rod Strickland       Karl Malone
# 0         Jason Kidd       Karl Malone
# 0         Jason Kidd  Shaquille O'Neal
# 0         Jason Kidd  Shaquille O'Neal
# 0       Andre Miller        Tim Duncan
# 0         Jason Kidd        Tim Duncan
# 0         Jason Kidd     Kevin Garnett
# 0         Steve Nash     Kevin Garnett
# 0         Steve Nash     Dirk Nowitzki
# 0         Steve Nash     Dirk Nowitzki
# 0         Chris Paul        Chris Paul
# 0         Chris Paul      LeBron James
# 0         Steve Nash      LeBron James
# 0         Steve Nash      LeBron James
# 0        Rajon Rondo      LeBron James
# 0        Rajon Rondo      LeBron James
# 0         Chris Paul      Kevin Durant
# 0         Chris Paul      James Harden
# 0        Rajon Rondo     Stephen Curry
# 0       James Harden      James Harden
# 0  Russell Westbrook      James Harden
# 0  Russell Westbrook      James Harden

# %%
summary.to_csv('../data/summary.csv', index = False)
