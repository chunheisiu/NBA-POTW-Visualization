# %%
import pandas as pd

nba = pd.read_csv('NBA_player_of_the_week.csv', parse_dates = ['Date'])

# %%
nba
# Out:
#       Active season                  Player                   Team Conference  \
# 0                 0  Micheal Ray Richardson        New Jersey Nets        NaN
# 1                 0             Derek Smith   Los Angeles Clippers        NaN
# 2                 0             Calvin Natt         Denver Nuggets        NaN
# 3                 0     Kareem Abdul-Jabbar     Los Angeles Lakers        NaN
# 4                 0              Larry Bird         Boston Celtics        NaN
# ...             ...                     ...                    ...        ...
# 1182              1       Russell Westbrook  Oklahoma City Thunder       West
# 1183              1   Giannis Antetokounmpo        Milwaukee Bucks       East
# 1184              1           Stephen Curry  Golden State Warriors       West
# 1185              1            Kemba Walker      Charlotte Hornets       East
# 1186              1            Nikola Jokic         Denver Nuggets       West
#
# ...

# %%
nba['Player'].nunique()
# Out:
# 282

# %%
nba.groupby('Team').agg({'Season':'max' , 'Date':'count'}).sort_values('Date', ascending = False)
# Out:
#                            Season  Date
# Team
# Los Angeles Lakers      2012-2013    71
# San Antonio Spurs       2017-2018    61
# Houston Rockets         2018-2019    60
# Cleveland Cavaliers     2017-2018    59
# Miami Heat              2017-2018    57
# Utah Jazz               2018-2019    50
# Golden State Warriors   2018-2019    46
# Phoenix Suns            2013-2014    45
# Orlando Magic           2018-2019    45
# Oklahoma City Thunder   2018-2019    45
# Denver Nuggets          2018-2019    45
# Chicago Bulls           2016-2017    44
# Boston Celtics          2016-2017    43
# Philadelphia Sixers     2018-2019    39
# New York Knicks         2017-2018    36
# Portland Trail Blazers  2018-2019    34
# Toronto Raptors         2018-2019    34
# Atlanta Hawks           2018-2019    33
# Milwaukee Bucks         2018-2019    32
# New Jersey Nets         2008-2009    31
# Detroit Pistons         2018-2019    30
# Dallas Mavericks        2015-2016    30
# ...

# %%
nba.groupby('Position').agg({'Season':'max' , 'Date':'count'}).sort_values('Date', ascending = False)
# Out:
#              Season  Date
# Position
# G         2018-2019   184
# SG        2018-2019   173
# C         2018-2019   164
# PF        2018-2019   142
# F         2018-2019   137
# PG        2018-2019   122
# SF        2017-2018   119
# FC        2018-2019    84
# GF        2018-2019    50
# F-C       2002-2003     9
# G-F       2003-2004     3

# %%
nba.loc[nba.Position == 'FC']
# Out:
#       Active season              Player                 Team Conference  \
# 65                0    Hot Rod Williams  Cleveland Cavaliers        NaN
# 308               0          Tim Duncan    San Antonio Spurs        NaN
# 312               0     Jayson Williams      New Jersey Nets        NaN
# 332               0          Tim Duncan    San Antonio Spurs        NaN
# 339               0          Tim Duncan    San Antonio Spurs        NaN
# ...             ...                 ...                  ...        ...
# 1037              0       Marcin Gortat   Washington Wizards       East
# 1089              0          Kevin Love  Cleveland Cavaliers       East
# 1104              0   LaMarcus Aldridge    San Antonio Spurs       West
# 1139              0  Kristaps Porzingis      New York Knicks       East
# 1174              1        Paul Millsap       Denver Nuggets       West
#
#            Date Position Height  Weight  Age  Draft Year  Seasons in league  \
# ...
